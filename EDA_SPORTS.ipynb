# %% [markdown]
# EXPLORATORY ANALYSIS OF SPORTS DATASET
#
# Dataset: https://bit.ly/34SRn3b
#
#
# In this dataset there are 2 sets of data one is matches dataset other is delivery data set

# %%
#importing libraries 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#importing matches dataset 
m=pd.read_csv('/content/drive/MyDrive/matches.csv')
m
# Out:
#         id  season  ...         umpire2                  umpire3
# 0        1    2017  ...        NJ Llong                      NaN
# 1        2    2017  ...          S Ravi                      NaN
# 2        3    2017  ...       CK Nandan                      NaN
# 3        4    2017  ...   C Shamshuddin                      NaN
# 4        5    2017  ...             NaN                      NaN
# ..     ...     ...  ...             ...                      ...
# 751  11347    2019  ...        O Nandan                   S Ravi
# 752  11412    2019  ...     Nitin Menon                Ian Gould
# 753  11413    2019  ...             NaN                      NaN
# 754  11414    2019  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415    2019  ...       Ian Gould              Nigel Llong
#
# [756 rows x 18 columns]

# %%
#importing delivery dataset
delv=pd.read_csv('/content/drive/MyDrive/deliveries.csv')
delv
# Out:
#         match_id  inning  ... dismissal_kind    fielder
# 0              1       1  ...            NaN        NaN
# 1              1       1  ...            NaN        NaN
# 2              1       1  ...            NaN        NaN
# 3              1       1  ...            NaN        NaN
# 4              1       1  ...            NaN        NaN
# ...          ...     ...  ...            ...        ...
# 179073     11415       2  ...            NaN        NaN
# 179074     11415       2  ...            NaN        NaN
# 179075     11415       2  ...        run out  KH Pandya
# 179076     11415       2  ...            NaN        NaN
# 179077     11415       2  ...            lbw        NaN
#
# [179078 rows x 21 columns]

# %% [markdown]
# DATA CLEANING AND PREPROCESSING
#
# matches dataset

# %%
m.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
m["city"]=m["city"].fillna(m['city'].mode()[0])
m["winner"]=m["winner"].fillna(m["winner"].mode()[0])
m["player_of_match"]=m["player_of_match"].fillna(m["player_of_match"].mode()[0])
m["umpire1"]=m["umpire1"].fillna(m["umpire1"].mode()[0])
m["umpire2"]=m["umpire2"].fillna(m["umpire2"].mode()[0])
m=m.drop(['umpire3'],axis=1)
m
# Out:
#         id  season  ...          umpire1         umpire2
# 0        1    2017  ...      AY Dandekar        NJ Llong
# 1        2    2017  ...   A Nand Kishore          S Ravi
# 2        3    2017  ...      Nitin Menon       CK Nandan
# 3        4    2017  ...     AK Chaudhary   C Shamshuddin
# 4        5    2017  ...  HDPK Dharmasena   C Shamshuddin
# ..     ...     ...  ...              ...             ...
# 751  11347    2019  ...    Nanda Kishore        O Nandan
# 752  11412    2019  ...      Nigel Llong     Nitin Menon
# 753  11413    2019  ...  HDPK Dharmasena   C Shamshuddin
# 754  11414    2019  ...    Sundaram Ravi  Bruce Oxenford
# 755  11415    2019  ...      Nitin Menon       Ian Gould
#
# [756 rows x 17 columns]

# %%
clean_m=m.isnull().sum()
clean_m
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
#heatmap for matches dataset 
sns.heatmap(m.isnull())

# %% [markdown]
# delveries data set cleaning

# %%
delv.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
d=delv.drop(["player_dismissed","dismissal_kind","fielder"],axis=1)
d
# Out:
#         match_id  inning  ... extra_runs total_runs
# 0              1       1  ...          0          0
# 1              1       1  ...          0          0
# 2              1       1  ...          0          4
# 3              1       1  ...          0          0
# 4              1       1  ...          2          2
# ...          ...     ...  ...        ...        ...
# 179073     11415       2  ...          0          1
# 179074     11415       2  ...          0          2
# 179075     11415       2  ...          0          1
# 179076     11415       2  ...          0          2
# 179077     11415       2  ...          0          0
#
# [179078 rows x 18 columns]

# %%
m
# Out:
#         id  season  ...          umpire1         umpire2
# 0        1    2017  ...      AY Dandekar        NJ Llong
# 1        2    2017  ...   A Nand Kishore          S Ravi
# 2        3    2017  ...      Nitin Menon       CK Nandan
# 3        4    2017  ...     AK Chaudhary   C Shamshuddin
# 4        5    2017  ...  HDPK Dharmasena   C Shamshuddin
# ..     ...     ...  ...              ...             ...
# 751  11347    2019  ...    Nanda Kishore        O Nandan
# 752  11412    2019  ...      Nigel Llong     Nitin Menon
# 753  11413    2019  ...  HDPK Dharmasena   C Shamshuddin
# 754  11414    2019  ...    Sundaram Ravi  Bruce Oxenford
# 755  11415    2019  ...      Nitin Menon       Ian Gould
#
# [756 rows x 17 columns]

# %% [markdown]
# VISUALIZATION OF DATA

# %%
#from matches counting the team that has won matches 
m.winner.value_counts()
# Out:
# Mumbai Indians                 113
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(45,10))
sns.set_theme(style="darkgrid")
sns.countplot(x=m['winner'])
plt.title("Count of no of win by each team in a season",size=20)
plt.xlabel("Winner team",size=20)
plt.ylabel("Count",size=20)
plt.xticks(size=12)
plt.yticks(size=12)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
#from matches dataset counting the player of match 
m.player_of_match.value_counts()
# Out:
# CH Gayle          25
# AB de Villiers    20
# MS Dhoni          17
# RG Sharma         17
# DA Warner         17
#                   ..
# RS Bopara          1
# M Ur Rahman        1
# K Ahmed            1
# GD McGrath         1
# WPUJC Vaas         1
# Name: player_of_match, Length: 226, dtype: int64

# %%
#top 10 player of match
m.player_of_match.value_counts().loc[lambda x: x>10]
# Out:
# CH Gayle          25
# AB de Villiers    20
# MS Dhoni          17
# RG Sharma         17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# V Kohli           12
# MEK Hussey        12
# AM Rahane         12
# AD Russell        11
# DR Smith          11
# A Mishra          11
# V Sehwag          11
# Name: player_of_match, dtype: int64

# %%
d
# Out:
#         match_id  inning  ... extra_runs total_runs
# 0              1       1  ...          0          0
# 1              1       1  ...          0          0
# 2              1       1  ...          0          4
# 3              1       1  ...          0          0
# 4              1       1  ...          2          2
# ...          ...     ...  ...        ...        ...
# 179073     11415       2  ...          0          1
# 179074     11415       2  ...          0          2
# 179075     11415       2  ...          0          1
# 179076     11415       2  ...          0          2
# 179077     11415       2  ...          0          0
#
# [179078 rows x 18 columns]

# %%
# top 10 batsman and total runs they have scored 
bm=pd.DataFrame(d.groupby('batsman').sum()['total_runs'])
bm.sort_values('total_runs',ascending=False).head(10)
# Out:
#                 total_runs
# batsman
# SK Raina              5651
# V Kohli               5616
# RG Sharma             5057
# DA Warner             4975
# S Dhawan              4876
# CH Gayle              4873
# RV Uthappa            4703
# MS Dhoni              4691
# AB de Villiers        4583
# G Gambhir             4485

# %%
#bowlers and there running rate 
bwl=d.groupby(["bowler"]).sum()
bwl['over']=d['bowler'].value_counts()/6
bwl['runs']=bwl['wide_runs']+bwl['noball_runs']+bwl['batsman_runs']
bwl['rate']=bwl['runs']/bwl['over']
bwl=bwl.sort_values('rate',ascending=False)
bwl.head(10)
# Out:
#                match_id  inning      over  ...  total_runs  runs       rate
# bowler                                     ...
# I Malhotra         1674      12  1.000000  ...          23    23  23.000000
# LPC Silva           480      12  1.000000  ...          21    21  21.000000
# B Chipli           1674      12  1.000000  ...          20    20  20.000000
# SN Khan           22638       4  0.333333  ...           6     6  18.000000
# P Prasanth         1764       6  1.000000  ...          18    18  18.000000
# RR Bhatkal         3840      24  2.000000  ...          35    35  17.500000
# CK Kapugedera      1548      28  2.833333  ...          49    49  17.294118
# S Sriram           4362      18  3.000000  ...          49    49  16.333333
# F du Plessis       1878      12  1.000000  ...          16    16  16.000000
# SPD Smith           716       4  0.333333  ...           5     5  15.000000
#
# [10 rows x 15 columns]
